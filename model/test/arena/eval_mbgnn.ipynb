# %% [markdown]
# ### from Co-evolution-based Metal-binding ResiduePrediction with Graph Neural Networks

# %% [markdown]
# #### metal

# %%
precision = 0.8832
recall = 0.7032
f1 = 0.7826

# %% [markdown]
# #### metal type

# %%
# outperforms LMetalSite and M-Ionic

precision = 0.7194
recall = 0.4924
f1 = 0.5543
