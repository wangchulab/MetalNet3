# %%
# input
rep_kegg_terms = "./data/rep_kegg_pathway.txt"
# output
fig_file = "./fig/rep_kegg_distribution.pdf"

# %%
lines = []
with open(rep_kegg_terms, "r") as f:
    lines = f.readlines()

data = []
for l in lines:
    if "(" in l and ")" in l:
        items = l.split()
        desc = " ".join(items[1:-1])
        num = int(items[-1][1:-1])
        data.append((desc, num))
data.sort(key=lambda x: x[1], reverse=True)
data = data[:10]
data
# Out:
# [('Metabolic pathways', 141),
#  ('Biosynthesis of secondary metabolites', 58),
#  ('Microbial metabolism in diverse environments', 50),
#  ('Carbon metabolism', 29),
#  ('Biosynthesis of amino acids', 23),
#  ('Biosynthesis of cofactors', 19),
#  ('Glycolysis / Gluconeogenesis', 16),
#  ('Pyruvate metabolism', 15),
#  ('Methane metabolism', 15),
#  ('Other carbon fixation pathways', 10)]

# %%
import matplotlib.pyplot as plt

plt.style.use(f"{PROJECT_DIR}/asset/metalnet.mplstyle")
plt.figure(figsize=(2.4, 1.6))
ax = plt.gca()
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

x = [i[0] for i in data]
y = [i[1] for i in data]
x.reverse()
y.reverse()

plt.barh(x, y)
plt.xlabel('Count')
plt.savefig(fig_file, bbox_inches="tight", transparent=True)
# Out:
# <BarContainer object of 10 artists>
# Text(0.5, 0, 'Count')
