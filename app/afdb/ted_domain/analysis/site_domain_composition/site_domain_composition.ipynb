# %%
# params
# from "../../2_info.sh"

x = ["one domain", "multiple domains", "mixed"]
y = [32291076, 1649455, 12202682]
sum(y) # total site number
# Out:
# 46143213

# %%
import matplotlib.pyplot as plt

plt.style.use(f"{PROJECT_DIR}/asset/metalnet.mplstyle")


plt.figure(figsize=(3, 3))
plt.pie(y, autopct="%.1f%%",)
plt.legend(
    labels=[# 'total protein',
            'single domain',
            'multiple domains',
            'mixed'],
    loc='center left',
    bbox_to_anchor=(1,.5)
)

plt.savefig("./fig/site_domain_composition.pdf", bbox_inches="tight", transparent=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x7ef7f3c63690>,
# ...
#  [Text(-0.646007706109711, 0.8903224380228039, ''),
#   Text(-0.2218856627613096, -1.0773888586118638, ''),
#   Text(0.7417118784343132, -0.8123198196458354, '')],
#  [Text(-0.35236783969620594, 0.48563042073971113, '70.0%'),
#   Text(-0.12102854332435069, -0.5876666501519257, '3.6%'),
#   Text(0.40457011550962535, -0.4430835379886375, '26.4%')])
